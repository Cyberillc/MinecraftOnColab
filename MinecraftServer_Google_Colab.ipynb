# %% [markdown]
# # **1º Create/Update the Server**
#
# The code below will create your server and automatically accept the EULA (dont forget to actually read the EULA !). When you use these code cells, your server will be ready to start!

# %% [markdown]
# **Download/Update the Minecraft Server**
#
# The code below will download Paper, a **very** optimized version of spigot that supports bukkit and spigot!
#
# The server files will be saved in Google Drive (in the Google account you choose or you are currently using).
#
# Also don't forget to check on https://papermc.io/downloads/paper to see if you are updated! :)

# %%
# sadly only 1.21 works for now on this new api :( (For Forge)
# Change "1.21.1" to the desired version.
# Available tested versions:
# - 1.21.4
# - 1.21.3
# - 1.21.2
# - 1.21.1
# - 1.21
# - 1.20.6
# - 1.20.5
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8
# Newer versions will work too as long as they still use the newest version of java

version = '1.21.4'

# Choose server type. Currently available versions:
# - paper (Most vanilla. It's the same as SPIGOT, bukkit but better and more optimized)
# - forge (For using MODS) [Note, installation takes approximately 10-15 minutes, wait for "COMPLETED" after executing the first step.]
# - fabric (For playing Fabric. It's an alternative to Forge thats "more optimized" and it supports snapshots!)

server_type = 'paper'

from google.colab import drive
import requests
import json

drive.mount('/content/drive')

# Create the directory which will be used for the server
! mkdir "/content/drive/My Drive/Minecraft-Server"
# %cd "/content/drive/My Drive/Minecraft-Server"

# Internal init...

a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
#print(a.json()["builds"][-1])
b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
#print(b.json()["downloads"]["application"]["name"])
print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])

paperURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

forgeURL = "https://centrojars.com/api/fetchJar/modded/forge/" + version # sadly only 1.21 works for now on this new api :(

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge-installer.jar'}
url = {
    'paper': (paperURL),
    'fabric': 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/1.0.1/fabric-installer-1.0.1.jar',
    'forge': (forgeURL)
    }

print('Downloading to Google Drive...')

r = requests.get(url[server_type])

if r.status_code == 200:
  with open('/content/drive/My Drive/Minecraft-Server/' + jar_name[server_type], 'wb') as f:
    f.write(r.content)
else:
  print('Error '+ str(r.status_code) + '! Most likely you put in a version of the game that doesnt even exist! Try running the code cell again if you think that shouldn\'t have happened :)')

# Running specific install path.
if server_type == 'fabric':
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
  # %cd "/content/drive/My Drive/Minecraft-Server"
  # !java -jar forge-installer.jar --installServer

# Saving config
colabconfig = {"server_type": server_type,
               "server_version": version,}

json.dump(colabconfig, open("colabconfig.json",'w'))

print('Completed Server Install !')

# Please read the file stored in your server folder before running this command.
# Also, go to https://www.minecraft.net/en-us/eula to read Minecraft's EULA! Its gonna be very important if you wanna make a big minecraft server!

# Make sure Drive is mounted
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/Minecraft-Server"
# !echo "eula=true" >> eula.txt

# %% [markdown]
# # **2º** This script will start the server! To stop it click on the same button you used to start it!
# [Download PlayIt-GG](https://github.com/playit-cloud/playit-minecraft-plugin/releases/latest/download/playit-minecraft-plugin.jar)

# %%
import os
import re
import json
import glob

# Update the package lists
# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, the google colab backend might have to use very old linux packages :("

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory to the Minecraft server folder on Google Drive
# %cd "/content/drive/My Drive/Minecraft-Server"
# !ls #list the directory contents (to check if that working directory was changed)

# Import config file.
if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"} # using default, if config doesn't exist.
  json.dump(colabconfig, open("colabconfig.json",'w'))


if colabconfig["server_type"] == "forge":
   version = colabconfig["server_version"]
   if colabconfig["server_version"] < "1.17":
    # !sudo apt-get install openjdk-15-jre-headless &>/dev/null && echo "Yay! OpenJDK 15 has been successfully installed." || echo "Failed to install OpenJDK 15 (Try again later)"
   else:
    # !sudo apt-get install openjdk-21-jre-headless &>/dev/null && echo "Yay! OpenJDK 21 has been successfully installed." || echo "Failed to install OpenJDK 23 (Try again later)."
else:
  # !sudo apt-get install openjdk-21-jre-headless &>/dev/null && echo "Yay! OpenJDK 21 has been successfully installed." || echo "Failed to install OpenJDK 23 (Try again later)"

#Perform java version check
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "21" :
  print("OpenJDK is working correctly, you're are good to go!")

# Server jar names.
jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar'}
jar_name = jar_list[colabconfig["server_type"]]

# Java arguments.
if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = "" # aiker's flags might negatively impact performance on non-paper servers.
memory_allocation = "-Xms10G -Xmx10G"

# !java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# apt cache successfully updated
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-Server
# AntiBackdoor-2024-12-22_02-34-10.txt  colabconfig.json	ops.json	      spigot.yml
# AntiBackdoor-2024-12-22_02-41-16.txt  commands.yml	paper.jar	      usercache.json
# AntiBackdoor-2024-12-22_12-02-11.txt  config		permissions.yml       version_history.json
# assets				      crash-reports	plugins		      versions
# banned-ips.json			      eula.txt		server.properties     whitelist.json
# banned-players.json		      help.yml		Server-World
# bukkit.yml			      libraries		Server-World_nether
# cache				      logs		Server-World_the_end
# Yay! OpenJDK 21 has been successfully installed.
# OpenJDK is working correctly, you're are good to go!
# Starting org.bukkit.craftbukkit.Main
# *** Warning, you've not updated in a while! ***
# *** Please download a new build as per instructions from https://papermc.io/downloads/paper ***
# [13:02:24 INFO]: [bootstrap] Running Java 21 (OpenJDK 64-Bit Server VM 21.0.5+11-Ubuntu-1ubuntu122.04; Ubuntu null) on Linux 6.1.85+ (amd64)
# [13:02:24 INFO]: [bootstrap] Loading Paper 1.21.4-15-master@bb76819 (2024-12-15T09:48:21Z) for Minecraft 1.21.4
# [13:02:25 INFO]: [PluginInitializerManager] Initializing plugins...
# [13:02:27 INFO]: [PluginRemapper] Remapping plugin 'plugins/AutoMod-0.3.7-alpha3.jar'...
# [13:02:32 INFO]: [PluginRemapper] Done remapping plugin 'plugins/AutoMod-0.3.7-alpha3.jar' in 4561ms.
# [13:02:33 INFO]: [PluginInitializerManager] Initialized 24 plugins
# [13:02:33 INFO]: [PluginInitializerManager] Bukkit plugins (24):
#  - AntiBackdoor (1.3.2), AntiWorldDownloader (2.7.1.3), AutoMod (0.3.7-alpha3), AutoUpdatePlugins (10.5), Chunky (1.4.28), ChunkyBorder (1.2.23), CoreProtect (22.4), DoubleDoors (1.4), GrimAC (2.3.69), InventoryRollbackPlus (1.6.21), Kryptonite (1.4.0), LightLeaf (1.0), LightNewbie (1.9), LuckPerms (5.4.150), PlayerStats (2.3), Protector (1.0), ProtocolLib (5.4.0-SNAPSHOT-738), ShieldFixes (1.0), TreeFeller (1.24.3), ViaBackwards (5.2.1-SNAPSHOT), ViaRewind (4.0.5-SNAPSHOT), ViaVersion (5.2.1-SNAPSHOT), hyperMOTD (1.0.2), playit-gg (0.1.4)
# [13:02:43 WARN]: resource-pack-id missing, using default of 485a8a0f-6844-36fb-9238-4c785e5c3e7f
# [13:02:43 INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [13:02:50 INFO]: Loaded 1370 recipes
# [13:02:50 INFO]: Loaded 1481 advancements
# [13:02:50 INFO]: [MCTypeRegistry] Initialising converters for DataConverter...
# [13:02:50 INFO]: [MCTypeRegistry] Finished initialising converters for DataConverter in 549.2ms
# [13:02:51 INFO]: Starting minecraft server version 1.21.4
# [13:02:51 WARN]: ****************************
# [13:02:51 WARN]: YOU ARE RUNNING THIS SERVER AS AN ADMINISTRATIVE OR ROOT USER. THIS IS NOT ADVISED.
# [13:02:51 WARN]: YOU ARE OPENING YOURSELF UP TO POTENTIAL RISKS WHEN DOING THIS.
# [13:02:51 WARN]: FOR MORE INFORMATION, SEE https://madelinemiller.dev/blog/root-minecraft-server/
# [13:02:51 WARN]: ****************************
# [13:02:51 INFO]: Loading properties
# [13:02:51 INFO]: This server is running Paper version 1.21.4-15-master@bb76819 (2024-12-15T09:48:21Z) (Implementing API version 1.21.4-R0.1-SNAPSHOT)
# [13:02:52 INFO]: [spark] This server bundles the spark profiler. For more information please visit https://docs.papermc.io/paper/profiling
# [13:02:52 INFO]: Server Ping Player Sample Count: 12
# [13:02:52 INFO]: Using 4 threads for Netty based IO
# [13:02:55 INFO]: [MoonriseCommon] Paper is using 1 worker threads, 1 I/O threads
# [13:02:55 INFO]: [ChunkTaskScheduler] Chunk system is using population gen parallelism: true
# [13:02:56 INFO]: Default game type: SURVIVAL
# [13:02:56 INFO]: Generating keypair
# [13:02:56 INFO]: Starting Minecraft server on *:25565
# [13:02:56 INFO]: Using epoll channel type
# [13:02:56 INFO]: Paper: Using libdeflate (Linux x86_64) compression from Velocity.
# [13:02:56 INFO]: Paper: Using OpenSSL 3.x.x (Linux x86_64) cipher from Velocity.
# [13:02:56 ERROR]: [ModernPluginLoadingStrategy] Ambiguous plugin name 'hyperMOTD' for files 'plugins/.paper-remapped/hypermotd-paper-1.0.2.jar' and 'plugins/.paper-remapped/hypermotd-paper-1.0.2.jar' in 'plugins/.paper-remapped'
# [13:02:56 ERROR]: [ModernPluginLoadingStrategy] Ambiguous plugin name 'LightNewbie' for files 'plugins/.paper-remapped/LightNewbie-1.9.jar' and 'plugins/.paper-remapped/LightNewbie-1.9.jar' in 'plugins/.paper-remapped'
# [13:02:56 ERROR]: [ModernPluginLoadingStrategy] Could not load 'plugins/.paper-remapped/ShieldFixes-1.0.jar' in 'plugins/.paper-remapped'
# org.bukkit.plugin.UnknownDependencyException: Unknown/missing dependency plugins: [packetevents]. Please download and install these plugins to run 'ShieldFixes'.
# 	at io.papermc.paper.plugin.entrypoint.strategy.modern.ModernPluginLoadingStrategy.loadProviders(ModernPluginLoadingStrategy.java:82) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at io.papermc.paper.plugin.storage.SimpleProviderStorage.enter(SimpleProviderStorage.java:38) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at io.papermc.paper.plugin.entrypoint.LaunchEntryPointHandler.enter(LaunchEntryPointHandler.java:40) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at org.bukkit.craftbukkit.CraftServer.loadPlugins(CraftServer.java:561) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.dedicated.DedicatedServer.initServer(DedicatedServer.java:289) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1236) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:341) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at java.base/java.lang.Thread.run(Thread.java:1583) ~[?:?]
# [13:02:58 INFO]: [SpigotLibraryLoader] [AutoMod] Loading 3 libraries... please wait
# [13:02:59 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/dataformat/jackson-dataformat-yaml/2.17.1/jackson-dataformat-yaml-2.17.1.pom
# [13:02:59 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/dataformat/jackson-dataformats-text/2.17.1/jackson-dataformats-text-2.17.1.pom
# [13:02:59 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/jackson-base/2.17.1/jackson-base-2.17.1.pom
# [13:02:59 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/jackson-bom/2.17.1/jackson-bom-2.17.1.pom
# [13:03:00 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/jackson-parent/2.17/jackson-parent-2.17.pom
# [13:03:00 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/oss-parent/58/oss-parent-58.pom
# [13:03:00 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/org/junit/junit-bom/5.10.2/junit-bom-5.10.2.pom
# [13:03:00 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-databind/2.17.1/jackson-databind-2.17.1.pom
# [13:03:01 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-annotations/2.17.1/jackson-annotations-2.17.1.pom
# [13:03:01 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-core/2.17.1/jackson-core-2.17.1.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-databind/2.16.1/jackson-databind-2.16.1.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/jackson-base/2.16.1/jackson-base-2.16.1.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/jackson-bom/2.16.1/jackson-bom-2.16.1.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/jackson-parent/2.16/jackson-parent-2.16.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/oss-parent/56/oss-parent-56.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/org/junit/junit-bom/5.9.2/junit-bom-5.9.2.pom
# [13:03:02 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-annotations/2.16.1/jackson-annotations-2.16.1.pom
# [13:03:03 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-core/2.16.1/jackson-core-2.16.1.pom
# [13:03:03 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/org/junit/junit-bom/5.9.3/junit-bom-5.9.3.pom
# [13:03:03 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/lettuce/lettuce-core/6.2.5.RELEASE/lettuce-core-6.2.5.RELEASE.pom
# [13:03:03 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-common/4.1.94.Final/netty-common-4.1.94.Final.pom
# [13:03:04 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-parent/4.1.94.Final/netty-parent-4.1.94.Final.pom
# [13:03:05 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-handler/4.1.94.Final/netty-handler-4.1.94.Final.pom
# [13:03:05 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-resolver/4.1.94.Final/netty-resolver-4.1.94.Final.pom
# [13:03:05 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-buffer/4.1.94.Final/netty-buffer-4.1.94.Final.pom
# [13:03:05 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-transport/4.1.94.Final/netty-transport-4.1.94.Final.pom
# [13:03:06 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-transport-native-unix-common/4.1.94.Final/netty-transport-native-unix-common-4.1.94.Final.pom
# [13:03:06 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-codec/4.1.94.Final/netty-codec-4.1.94.Final.pom
# [13:03:06 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/projectreactor/reactor-core/3.4.31/reactor-core-3.4.31.pom
# [13:03:07 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/dataformat/jackson-dataformat-yaml/2.17.1/jackson-dataformat-yaml-2.17.1.jar
# [13:03:07 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-core/2.17.1/jackson-core-2.17.1.jar
# [13:03:07 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/lettuce/lettuce-core/6.2.5.RELEASE/lettuce-core-6.2.5.RELEASE.jar
# [13:03:07 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-common/4.1.94.Final/netty-common-4.1.94.Final.jar
# [13:03:07 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-annotations/2.16.1/jackson-annotations-2.16.1.jar
# [13:03:07 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/com/fasterxml/jackson/core/jackson-databind/2.16.1/jackson-databind-2.16.1.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-handler/4.1.94.Final/netty-handler-4.1.94.Final.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-resolver/4.1.94.Final/netty-resolver-4.1.94.Final.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-buffer/4.1.94.Final/netty-buffer-4.1.94.Final.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-transport-native-unix-common/4.1.94.Final/netty-transport-native-unix-common-4.1.94.Final.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-codec/4.1.94.Final/netty-codec-4.1.94.Final.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/netty/netty-transport/4.1.94.Final/netty-transport-4.1.94.Final.jar
# [13:03:08 INFO]: [SpigotLibraryLoader] Downloading https://repo.maven.apache.org/maven2/io/projectreactor/reactor-core/3.4.31/reactor-core-3.4.31.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/com/fasterxml/jackson/dataformat/jackson-dataformat-yaml/2.17.1/jackson-dataformat-yaml-2.17.1.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/org/yaml/snakeyaml/2.2/snakeyaml-2.2.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/com/fasterxml/jackson/core/jackson-core/2.17.1/jackson-core-2.17.1.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/com/fasterxml/jackson/core/jackson-databind/2.16.1/jackson-databind-2.16.1.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/com/fasterxml/jackson/core/jackson-annotations/2.16.1/jackson-annotations-2.16.1.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/lettuce/lettuce-core/6.2.5.RELEASE/lettuce-core-6.2.5.RELEASE.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-common/4.1.94.Final/netty-common-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-handler/4.1.94.Final/netty-handler-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-resolver/4.1.94.Final/netty-resolver-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-buffer/4.1.94.Final/netty-buffer-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-transport-native-unix-common/4.1.94.Final/netty-transport-native-unix-common-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-codec/4.1.94.Final/netty-codec-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/netty/netty-transport/4.1.94.Final/netty-transport-4.1.94.Final.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/io/projectreactor/reactor-core/3.4.31/reactor-core-3.4.31.jar
# [13:03:09 INFO]: [SpigotLibraryLoader] [AutoMod] Loaded library /content/drive/My Drive/Minecraft-Server/libraries/org/reactivestreams/reactive-streams/1.0.4/reactive-streams-1.0.4.jar
# [13:03:10 WARN]: [org.bukkit.craftbukkit.legacy.CraftLegacy] Initializing Legacy Material Support. Unless you have legacy plugins and/or data this is a bug!
# [13:03:29 WARN]: Legacy plugin Protector v1.0 does not specify an api-version.
# [13:03:29 WARN]: Legacy plugin AntiWorldDownloader v2.7.1.3 does not specify an api-version.
# [13:03:29 WARN]: Legacy plugin AutoUpdatePlugins v10.5 does not specify an api-version.
# [13:03:29 INFO]: [ViaVersion] Loading server plugin ViaVersion v5.2.1-SNAPSHOT
# [13:03:29 INFO]: [ViaVersion] ViaVersion 5.2.1-SNAPSHOT is now loaded. Registering protocol transformers and injecting...
# [13:03:31 INFO]: [ViaVersion] Loading block connection mappings ...
# [13:03:32 INFO]: [ViaVersion] Using FastUtil Long2ObjectOpenHashMap for block connections
# [13:03:33 INFO]: [ViaBackwards] Loading translations...
# [13:03:33 INFO]: [ViaBackwards] Registering protocols...
# [13:03:34 INFO]: [ViaRewind] Registering protocols...
# [13:03:34 INFO]: [ViaBackwards] Loading server plugin ViaBackwards v5.2.1-SNAPSHOT
# [13:03:34 INFO]: [CoreProtect] Loading server plugin CoreProtect v22.4
# [13:03:34 INFO]: [Chunky] Loading server plugin Chunky v1.4.28
# [13:03:34 INFO]: [ProtocolLib] Loading server plugin ProtocolLib v5.4.0-SNAPSHOT-738
# [13:03:35 WARN]: [ProtocolLib] Version (MC: 1.21.4) has not yet been tested! Proceed with caution.
# [13:03:35 INFO]: [ViaRewind] Loading server plugin ViaRewind v4.0.5-SNAPSHOT
# [13:03:35 INFO]: [AutoMod] Loading server plugin AutoMod v0.3.7-alpha3
# [13:03:35 INFO]: [TreeFeller] Loading server plugin TreeFeller v1.24.3
# [13:03:35 INFO]: [PlayerStats] Loading server plugin PlayerStats v2.3
# [13:03:35 INFO]: [InventoryRollbackPlus] Loading server plugin InventoryRollbackPlus v1.6.21
# [13:03:35 INFO]: [LuckPerms] Loading server plugin LuckPerms v5.4.150
# [13:03:36 INFO]: [LightLeaf] Loading server plugin LightLeaf v1.0
# [13:03:36 INFO]: [LightNewbie] Loading server plugin LightNewbie v1.9
# [13:03:36 INFO]: [ChunkyBorder] Loading server plugin ChunkyBorder v1.2.23
# [13:03:36 INFO]: [DoubleDoors] Loading server plugin DoubleDoors v1.4
# [13:03:36 INFO]: [GrimAC] Loading server plugin GrimAC v2.3.69
# [13:03:36 INFO]: [GrimAC] Loading PacketEvents...
# [13:03:42 INFO]: [Protector] Loading server plugin Protector v1.0
# [13:03:42 INFO]: [AntiWorldDownloader] Loading server plugin AntiWorldDownloader v2.7.1.3
# [13:03:42 INFO]: [Kryptonite] Loading server plugin Kryptonite v1.4.0
# [13:03:42 INFO]: [playit-gg] Loading server plugin playit-gg v0.1.4
# [13:03:42 INFO]: [hyperMOTD] Loading server plugin hyperMOTD v1.0.2
# [13:03:42 INFO]: [AntiBackdoor] Loading server plugin AntiBackdoor v1.3.2
# [13:03:42 INFO]: [AutoUpdatePlugins] Loading server plugin AutoUpdatePlugins v10.5
# [13:03:42 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [13:03:42 INFO]: [ProtocolLib] Enabling ProtocolLib v5.4.0-SNAPSHOT-738
# [13:03:42 INFO]: [ViaRewind] Enabling ViaRewind v4.0.5-SNAPSHOT
# [13:03:42 INFO]: [LuckPerms] Enabling LuckPerms v5.4.150
# [13:03:45 INFO]:         __
# [13:03:45 INFO]:   |    |__)   LuckPerms v5.4.150
# [13:03:45 INFO]:   |___ |      Running on Bukkit - Paper
# [13:03:45 INFO]:
# [13:03:45 INFO]: [LuckPerms] Loading configuration...
# [13:03:47 INFO]: [LuckPerms] Loading storage provider... [H2]
# [13:03:48 INFO]: [LuckPerms] Loading internal permission managers...
# [13:03:48 INFO]: [LuckPerms] Performing initial data load...
# [13:03:49 INFO]: [LuckPerms] Successfully enabled. (took 6081ms)
# [13:03:49 INFO]: [AntiBackdoor] Enabling AntiBackdoor v1.3.2
# [13:03:49 INFO]:  -> AntiBackdoor > Checking AutoUpdatePlugins...
# [13:03:49 INFO]:  -> AntiBackdoor > Checking AntiBackdoor...
# [13:03:49 INFO]:  -> AntiBackdoor > Checking hyperMOTD...
# [13:03:49 INFO]:  -> AntiBackdoor > Checking CoreProtect...
# [13:03:49 INFO]:  -> AntiBackdoor > Checking playit-gg...
# [13:03:50 INFO]:  -> AntiBackdoor > Checking Kryptonite...
# [13:03:50 INFO]:  -> AntiBackdoor > Checking AntiWorldDownloader...
# [13:03:50 INFO]:  -> AntiBackdoor > Checking Protector...
# [13:03:50 INFO]:  -> AntiBackdoor > Checking GrimAC...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking DoubleDoors...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking ShieldFixes...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking Chunky...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking ChunkyBorder...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking LightNewbie...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking LightLeaf...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking LuckPerms...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking ViaBackwards...
# [13:03:51 INFO]:  -> AntiBackdoor > Checking ViaVersion...
# [13:03:52 INFO]:  -> AntiBackdoor > Checking ViaRewind...
# [13:03:52 INFO]:  -> AntiBackdoor > Checking InventoryRollbackPlus...
# [13:03:52 INFO]:  -> AntiBackdoor > Checking PlayerStats...
# [13:03:52 INFO]:  -> AntiBackdoor > Checking ProtocolLib...
# [13:03:53 INFO]:  -> AntiBackdoor > Checking TreeFeller...
# [13:03:53 INFO]:  -> AntiBackdoor > Checking hyperMOTD...
# [13:03:53 INFO]:  -> AntiBackdoor > Checking LightNewbie...
# [13:03:53 INFO]:  -> AntiBackdoor > Checking AutoMod...
# [13:03:53 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [13:03:53 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [13:03:53 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [13:03:53 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [13:03:53 INFO]: Preparing level "Server-World"
# [13:03:55 INFO]: Preparing start region for dimension minecraft:overworld
# [13:03:55 INFO]: Preparing spawn area: 0%
# [13:03:55 INFO]: Preparing spawn area: 0%
# [13:03:56 INFO]: Preparing spawn area: 2%
# [13:03:56 INFO]: Preparing spawn area: 34%
# [13:03:58 INFO]: Preparing spawn area: 77%
# [13:03:58 INFO]: Preparing spawn area: 77%
# [13:03:58 INFO]: Time elapsed: 2916 ms
# [13:03:58 INFO]: Preparing start region for dimension minecraft:the_nether
# [13:03:58 INFO]: Preparing spawn area: 0%
# [13:03:58 INFO]: Preparing spawn area: 10%
# [13:03:59 INFO]: Preparing spawn area: 61%
# [13:03:59 INFO]: Time elapsed: 1118 ms
# [13:03:59 INFO]: Preparing start region for dimension minecraft:the_end
# [13:03:59 INFO]: Preparing spawn area: 0%
# [13:03:59 INFO]: Preparing spawn area: 18%
# [13:04:00 INFO]: Preparing spawn area: 44%
# [13:04:00 INFO]: Preparing spawn area: 85%
# [13:04:00 INFO]: Time elapsed: 1581 ms
# [13:04:00 INFO]: [ViaVersion] Enabling ViaVersion v5.2.1-SNAPSHOT
# [13:04:00 INFO]: [ViaVersion] ViaVersion detected server version: 1.21.4 (769)
# [13:04:01 INFO]: [ViaBackwards] Enabling ViaBackwards v5.2.1-SNAPSHOT
# [13:04:01 INFO]: [CoreProtect] Enabling CoreProtect v22.4
# [13:04:03 INFO]: [CoreProtect] CoreProtect has been successfully enabled!
# [13:04:03 INFO]: [CoreProtect] Using SQLite for data storage.
# [13:04:03 INFO]: --------------------
# [13:04:03 INFO]: [CoreProtect] Enjoy CoreProtect? Join our Discord!
# [13:04:03 INFO]: [CoreProtect] Discord: www.coreprotect.net/discord/
# [13:04:03 INFO]: --------------------
# [13:04:03 INFO]: [Chunky] Enabling Chunky v1.4.28
# [13:04:03 INFO]: [AutoMod] Enabling AutoMod v0.3.7-alpha3
# [13:04:03 INFO]: [AutoMod] === AutoMod ===
# [13:04:03 INFO]: [AutoMod] §cDISCLAIMER: This plugin uses the Perspective API by Google. By using this plugin, you agree to Google's Privacy Policy.
# [13:04:03 INFO]: [AutoMod] §cAnd make sure to have a fast internet connection, as this plugin uses a lot of network I/O.
# [13:04:03 INFO]: [AutoMod] Loading settings & messages...
# [13:04:04 ERROR]: Error occurred while enabling AutoMod v0.3.7-alpha3 (Is it up to date?)
# java.lang.NoSuchMethodError: 'void com.fasterxml.jackson.core.base.GeneratorBase.<init>(int, com.fasterxml.jackson.core.ObjectCodec, com.fasterxml.jackson.core.io.IOContext)'
# 	at com.fasterxml.jackson.dataformat.yaml.YAMLGenerator.<init>(YAMLGenerator.java:299) ~[?:?]
# 	at com.fasterxml.jackson.dataformat.yaml.YAMLFactory._createGenerator(YAMLFactory.java:532) ~[?:?]
# 	at com.fasterxml.jackson.dataformat.yaml.YAMLFactory.createGenerator(YAMLFactory.java:491) ~[?:?]
# 	at com.fasterxml.jackson.databind.ObjectMapper.createGenerator(ObjectMapper.java:1203) ~[jackson-databind-2.13.4.2.jar:2.13.4.2]
# 	at com.fasterxml.jackson.databind.ObjectMapper.writeValue(ObjectMapper.java:3763) ~[jackson-databind-2.13.4.2.jar:2.13.4.2]
# 	at AutoMod-0.3.7-alpha3.jar/it.unilix.yaml.YamlFile.setFileObj(YamlFile.kt:128) ~[AutoMod-0.3.7-alpha3.jar:?]
# 	at AutoMod-0.3.7-alpha3.jar/com.nextdevv.automod.configs.ConfigLoader.loadSettings(ConfigLoader.java:29) ~[AutoMod-0.3.7-alpha3.jar:?]
# 	at AutoMod-0.3.7-alpha3.jar/com.nextdevv.automod.AutoMod.loadConfigurations(AutoMod.java:98) ~[AutoMod-0.3.7-alpha3.jar:?]
# 	at AutoMod-0.3.7-alpha3.jar/com.nextdevv.automod.AutoMod.onEnable(AutoMod.java:47) ~[AutoMod-0.3.7-alpha3.jar:?]
# 	at org.bukkit.plugin.java.JavaPlugin.setEnabled(JavaPlugin.java:288) ~[paper-api-1.21.4-R0.1-SNAPSHOT.jar:?]
# 	at io.papermc.paper.plugin.manager.PaperPluginInstanceManager.enablePlugin(PaperPluginInstanceManager.java:202) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at io.papermc.paper.plugin.manager.PaperPluginManagerImpl.enablePlugin(PaperPluginManagerImpl.java:109) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at org.bukkit.plugin.SimplePluginManager.enablePlugin(SimplePluginManager.java:520) ~[paper-api-1.21.4-R0.1-SNAPSHOT.jar:?]
# 	at org.bukkit.craftbukkit.CraftServer.enablePlugin(CraftServer.java:655) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at org.bukkit.craftbukkit.CraftServer.enablePlugins(CraftServer.java:604) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.MinecraftServer.loadWorld0(MinecraftServer.java:769) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.MinecraftServer.loadLevel(MinecraftServer.java:531) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.dedicated.DedicatedServer.initServer(DedicatedServer.java:326) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.MinecraftServer.runServer(MinecraftServer.java:1236) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at net.minecraft.server.MinecraftServer.lambda$spin$0(MinecraftServer.java:341) ~[paper-1.21.4.jar:1.21.4-15-bb76819]
# 	at java.base/java.lang.Thread.run(Thread.java:1583) ~[?:?]
# [13:04:04 INFO]: [AutoMod] Disabling AutoMod v0.3.7-alpha3
# [13:04:04 INFO]: [AutoMod] === AutoMod ===
# [13:04:04 INFO]: [AutoMod] Saving caches...
# [13:04:04 WARN]: [AutoMod] Cache folder is not initialized. Caches will not be saved.
# [13:04:04 INFO]: [AutoMod] AutoMod has been disabled.
# [13:04:04 INFO]: [AutoMod] === AutoMod ===
# [13:04:04 INFO]: [TreeFeller] Enabling TreeFeller v1.24.3
# [13:04:04 INFO]: [TreeFeller] TreeFeller has been enabled! (Version 1.24.3) by ThizThizzyDizzy
# [13:04:05 INFO]: [TreeFeller] Server version: 1.21.4-R0.1-SNAPSHOT
# [13:04:05 INFO]: [TreeFeller] Loaded global values:
# [13:04:05 INFO]: [TreeFeller] - Startup Logs: true
# [13:04:05 INFO]: [TreeFeller] - Default Enabled: true
# [13:04:05 INFO]: [TreeFeller] - Scan Distance: 256
# [13:04:05 INFO]: [TreeFeller] - Leaf Detect Range: 6
# [13:04:05 INFO]: [TreeFeller] - Leaf Break Range: 6
# [13:04:05 INFO]: [TreeFeller] - Required Logs: 4
# [13:04:05 INFO]: [TreeFeller] - Required Leaves: 10
# [13:04:05 INFO]: [TreeFeller] - Max Logs: 250
# [13:04:05 INFO]: [TreeFeller] - Max Height: 5
# [13:04:05 INFO]: [TreeFeller] - Allow Partial: false
# [13:04:05 INFO]: [TreeFeller] - Allow Partial Tool: false
# [13:04:05 INFO]: [TreeFeller] - Player Leaves: false
# [13:04:05 INFO]: [TreeFeller] - Diagonal Leaves: false
# [13:04:05 INFO]: [TreeFeller] - Ignore Leaf Data: false
# [13:04:05 INFO]: [TreeFeller] - Require Cross Section: false
# [13:04:05 INFO]: [TreeFeller] - Force Distance Check: false
# [13:04:05 INFO]: [TreeFeller] - Decorations: [snow, vines, cocoa, weeping vines, moss]
# [13:04:05 INFO]: [TreeFeller] - Max Horizontal Trunk Pillar Length: 6
# [13:04:05 INFO]: [TreeFeller] - Min Vertical Log Ratio: 0.5
# [13:04:05 INFO]: [TreeFeller] - Cutting Animation: false
# [13:04:05 INFO]: [TreeFeller] - Anim Delay: 1
# [13:04:05 INFO]: [TreeFeller] - Replant Saplings: false
# [13:04:05 INFO]: [TreeFeller] - Use Tree Saplings: true
# [13:04:05 INFO]: [TreeFeller] - Use Inventory Saplings: false
# [13:04:05 INFO]: [TreeFeller] - Spawn Saplings: 0
# [13:04:05 INFO]: [TreeFeller] - Sapling Timeout: 50
# [13:04:05 INFO]: [TreeFeller] - Grass: [GRASS_BLOCK, DIRT, PODZOL]
# [13:04:05 INFO]: [TreeFeller] - Root Distance: 6
# [13:04:05 INFO]: [TreeFeller] - Log Behavior: BREAK
# [13:04:05 INFO]: [TreeFeller] - Leaf Behavior: BREAK
# [13:04:05 INFO]: [TreeFeller] - Fall Hurt Amount: 2.0
# [13:04:05 INFO]: [TreeFeller] - Fall Hurt Max: 40
# [13:04:05 INFO]: [TreeFeller] - Directional Fall Behavior: RANDOM
# [13:04:05 INFO]: [TreeFeller] - Overridables: [AIR, FERN, CAVE_AIR, TALL_GRASS, SEAGRASS, TALL_SEAGRASS, LARGE_FERN, WATER]
# [13:04:05 INFO]: [TreeFeller] - Lock Fall Cardinal: false
# [13:04:05 INFO]: [TreeFeller] - Directional Fall Velocity: 0.35
# [13:04:05 INFO]: [TreeFeller] - Vertical Fall Velocity: 0.05
# [13:04:05 INFO]: [TreeFeller] - Explosive Fall Velocity: 0.0
# [13:04:05 INFO]: [TreeFeller] - Random Fall Velocity: 0.0
# [13:04:05 INFO]: [TreeFeller] - Fall Delay: 0
# [13:04:05 INFO]: [TreeFeller] - Respect Unbreaking: true
# [13:04:05 INFO]: [TreeFeller] - Respect Unbreakable: true
# [13:04:05 INFO]: [TreeFeller] - Damage Mult: 1.0
# [13:04:05 INFO]: [TreeFeller] - Stacked Tools: false
# [13:04:05 INFO]: [TreeFeller] - Leaf Fortune: true
# [13:04:05 INFO]: [TreeFeller] - Leaf Silk Touch: false
# [13:04:05 INFO]: [TreeFeller] - Log Fortune: true
# [13:04:05 INFO]: [TreeFeller] - Log Silk Touch: true
# [13:04:05 INFO]: [TreeFeller] - Leave Stump: false
# [13:04:05 INFO]: [TreeFeller] - Rotate Logs: true
# [13:04:05 INFO]: [TreeFeller] - Drop Conversions: {SPRUCE_WOOD=SPRUCE_LOG, ACACIA_WOOD=ACACIA_LOG, BIRCH_WOOD=BIRCH_LOG, WARPED_HYPHAE=WARPED_STEM, JUNGLE_WOOD=JUNGLE_LOG, CRIMSON_HYPHAE=CRIMSON_STEM, OAK_WOOD=OAK_LOG, DARK_OAK_WOOD=DARK_OAK_LOG}
# [13:04:05 INFO]: [TreeFeller] - Leaf Drop Chance: 1.0
# [13:04:05 INFO]: [TreeFeller] - Log Drop Chance: 1.0
# [13:04:05 INFO]: [TreeFeller] - Effects: []
# [13:04:05 INFO]: [TreeFeller] - Consumed Food Base: 0.0
# [13:04:05 INFO]: [TreeFeller] - Consumed Food Logs: 0.0
# [13:04:05 INFO]: [TreeFeller] - Consumed Food Leaves: 0.0
# [13:04:05 INFO]: [TreeFeller] - Consumed Health Base: 0.0
# [13:04:05 INFO]: [TreeFeller] - Consumed Health Logs: 0.0
# [13:04:05 INFO]: [TreeFeller] - Consumed Health Leaves: 0.0
# [13:04:05 INFO]: [TreeFeller] - Prevent Breakage: false
# [13:04:05 INFO]: [TreeFeller] - Enable Adventure: false
# [13:04:05 INFO]: [TreeFeller] - Enable Survival: true
# [13:04:05 INFO]: [TreeFeller] - Enable Creative: false
# [13:04:05 INFO]: [TreeFeller] - With Sneak: false
# [13:04:05 INFO]: [TreeFeller] - Without Sneak: true
# [13:04:05 INFO]: [TreeFeller] - World Blacklist: false
# [13:04:05 INFO]: [TreeFeller] - Cascade: false
# [13:04:05 INFO]: [TreeFeller] - Parallel Cascade Limit: 1
# [13:04:05 INFO]: [TreeFeller] - Cascade Check Limit: 64
# [13:04:05 INFO]: [TreeFeller] - MMOCore Trunk XP: {woodcutting=1.0}
# [13:04:05 INFO]: [TreeFeller] - MMOCore Leaves XP: {woodcutting=0.0}
# [13:04:05 INFO]: [TreeFeller] - MMOCore Tree XP: {woodcutting=0.0}
# [13:04:05 INFO]: [TreeFeller] - MMOCore Emulate Regen: false
# [13:04:05 INFO]: [TreeFeller] - Compatibility MMOCore: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility Jobs: true
# [13:04:05 INFO]: [TreeFeller] - MCMMO Double Drops: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility mcMMO: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility mcMMO Classic: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility CoreProtect: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility WorldGuard: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility GriefPrevention: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility Towny: true
# [13:04:05 INFO]: [TreeFeller] - OreRegenerator Regen Delay: 1200
# [13:04:05 INFO]: [TreeFeller] - Compatibility OreRegenerator: false
# [13:04:05 INFO]: [TreeFeller] - Compatibility Drop2Inventory: true
# [13:04:05 INFO]: [TreeFeller] - EcoSkills Trunk XP: {Woodcutting=1.0}
# [13:04:05 INFO]: [TreeFeller] - EcoSkills Leaves XP: {woodcutting=0.0}
# [13:04:05 INFO]: [TreeFeller] - EcoSkills Tree XP: {woodcutting=0.0}
# [13:04:05 INFO]: [TreeFeller] - Compatibility EcoSkills: true
# [13:04:05 INFO]: [TreeFeller] - EcoJobs Apply Multipliers: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility EcoJobs: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility LogBlock Legacy: false
# [13:04:05 INFO]: [TreeFeller] - Compatibility LogBlock: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility Lands: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility PlaceholderAPI: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility SaberFactions: true
# [13:04:05 INFO]: [TreeFeller] - AureliumSkills Trunk XP: {foraging=1.0}
# [13:04:05 INFO]: [TreeFeller] - AureliumSkills Leaves XP: {foraging=0.0}
# [13:04:05 INFO]: [TreeFeller] - AureliumSkills Apply Modifiers: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility AureliumSkills: true
# [13:04:05 INFO]: [TreeFeller] - AuraSkills Trunk XP: {foraging=1.0}
# [13:04:05 INFO]: [TreeFeller] - AuraSkills Leaves XP: {foraging=0.0}
# [13:04:05 INFO]: [TreeFeller] - AuraSkills Apply Modifiers: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility AuraSkills: true
# [13:04:05 INFO]: [TreeFeller] - Compatibility BlockRegen: false
# [13:04:05 INFO]: [TreeFeller] - Compatibility Prism: true
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: OAK_LOG, OAK_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: OAK_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [OAK_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: BIRCH_LOG, BIRCH_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: BIRCH_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [BIRCH_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: SPRUCE_LOG, SPRUCE_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: SPRUCE_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [SPRUCE_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 4
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: JUNGLE_LOG, JUNGLE_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: JUNGLE_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [JUNGLE_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 4
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: DARK_OAK_LOG, DARK_OAK_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: DARK_OAK_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [DARK_OAK_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 4
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: ACACIA_LOG, ACACIA_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: ACACIA_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [ACACIA_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: OAK_LOG, OAK_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: AZALEA_LEAVES, FLOWERING_AZALEA_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Diagonal Leaves: true
# [13:04:05 INFO]: [TreeFeller] - Sapling: [AZALEA, FLOWERING_AZALEA]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: MANGROVE_LOG, MANGROVE_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: MANGROVE_ROOTS, MANGROVE_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Leaf Detect Range: 16
# [13:04:05 INFO]: [TreeFeller] - Leaf Break Range: 16
# [13:04:05 INFO]: [TreeFeller] - Required Logs: 3
# [13:04:05 INFO]: [TreeFeller] - Diagonal Leaves: true
# [13:04:05 INFO]: [TreeFeller] - Max Horizontal Trunk Pillar Length: 16
# [13:04:05 INFO]: [TreeFeller] - Max Trunks: 16
# [13:04:05 INFO]: [TreeFeller] - Sapling: [MANGROVE_PROPAGULE]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] - Roots: [MANGROVE_ROOTS]
# [13:04:05 INFO]: [TreeFeller] - Root Distance: 16
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: CHERRY_LOG, CHERRY_WOOD
# [13:04:05 INFO]: [TreeFeller] - Leaves: CHERRY_LEAVES
# [13:04:05 INFO]: [TreeFeller] - Sapling: [CHERRY_SAPLING]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: CRIMSON_STEM, CRIMSON_HYPHAE
# [13:04:05 INFO]: [TreeFeller] - Leaves: NETHER_WART_BLOCK, SHROOMLIGHT
# [13:04:05 INFO]: [TreeFeller] - Leaf Detect Range: 8
# [13:04:05 INFO]: [TreeFeller] - Leaf Break Range: 8
# [13:04:05 INFO]: [TreeFeller] - Diagonal Leaves: true
# [13:04:05 INFO]: [TreeFeller] - Sapling: [CRIMSON_FUNGUS]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] - Grass: [CRIMSON_NYLIUM]
# [13:04:05 INFO]: [TreeFeller] Loaded Tree!
# [13:04:05 INFO]: [TreeFeller] - Trunk: WARPED_STEM, WARPED_HYPHAE
# [13:04:05 INFO]: [TreeFeller] - Leaves: WARPED_WART_BLOCK, SHROOMLIGHT
# [13:04:05 INFO]: [TreeFeller] - Leaf Detect Range: 8
# [13:04:05 INFO]: [TreeFeller] - Leaf Break Range: 8
# [13:04:05 INFO]: [TreeFeller] - Diagonal Leaves: true
# [13:04:05 INFO]: [TreeFeller] - Sapling: [WARPED_FUNGUS]
# [13:04:05 INFO]: [TreeFeller] - Max Saplings: 1
# [13:04:05 INFO]: [TreeFeller] - Grass: [WARPED_NYLIUM]
# [13:04:05 INFO]: [TreeFeller] Loaded tool: WOODEN_AXE
# [13:04:05 INFO]: [TreeFeller] Loaded tool: STONE_AXE
# [13:04:05 INFO]: [TreeFeller] Loaded tool: IRON_AXE
# [13:04:05 INFO]: [TreeFeller] Loaded tool: GOLDEN_AXE
# [13:04:05 INFO]: [TreeFeller] Loaded tool: DIAMOND_AXE
# [13:04:05 INFO]: [TreeFeller] Loaded tool: NETHERITE_AXE
# [13:04:05 INFO]: [PlayerStats] Enabling PlayerStats v2.3
# [13:04:06 INFO]: [PlayerStats] Loaded 0 excluded players from file (1ms)
# [13:04:06 INFO]: [PlayerStats] Loaded 0 offline players (32ms)
# [13:04:07 INFO]: [PlayerStats] Enabled PlayerStats!
# [13:04:07 INFO]: [InventoryRollbackPlus] Enabling InventoryRollbackPlus v1.6.21
# [13:04:07 INFO]: [InventoryRollbackPlus] Attempting support for version: 1.21.4-15-bb76819 (MC: 1.21.4)
# [13:04:07 INFO]: [InventoryRollbackPlus] Using CraftBukkit version: v1_21_R3
# [13:04:07 INFO]: [InventoryRollbackPlus] Inventory backup data is set to save to: YAML
# [13:04:07 INFO]: [InventoryRollbackPlus] bStats are enabled
# [13:04:07 INFO]: [LightLeaf] Enabling LightLeaf v1.0
# [13:04:07 INFO]: [LightNewbie] Enabling LightNewbie v1.9
# [13:04:07 INFO]: [LightNewbie] LightNewbie plugin has been enabled!
# [13:04:07 INFO]: [ChunkyBorder] Enabling ChunkyBorder v1.2.23
# [13:04:07 INFO]: [DoubleDoors] Enabling DoubleDoors v1.4
# [13:04:07 INFO]: [DoubleDoors] DoubleDoors is starting up...
# [13:04:07 INFO]: [DoubleDoors] DoubleDoors has been enabled!
# [13:04:07 INFO]: [GrimAC] Enabling GrimAC v2.3.69
# [13:04:07 INFO]: [GrimAC] Registering singular bukkit event... (PistonEvent)
# [13:04:08 INFO]: [GrimAC] Registering packets...
# [13:04:08 INFO]: [GrimAC] Registering tick schedulers...
# [13:04:08 INFO]: [GrimAC] [ACF] Enabled Asynchronous Tab Completion Support!
# [13:04:08 INFO]: [Protector] Enabling Protector v1.0*
# [13:04:09 INFO]: [Protector] §aProtector has been enabled
# [13:04:09 INFO]: [AntiWorldDownloader] Enabling AntiWorldDownloader v2.7.1.3*
# [13:04:09 INFO]: [AntiWorldDownloader] AWD has been enabled! (Version: 2.7.1.3)
# [13:04:09 INFO]: [Kryptonite] Enabling Kryptonite v1.4.0
# [13:04:09 INFO]: [Kryptonite]
# [13:04:09 INFO]: [Kryptonite] █▄▀ █▀█ █▄█ █▀█ ▀█▀ █▀█ █▄ █ █ ▀█▀ █▀▀
# [13:04:09 INFO]: [Kryptonite] █ █ █▀▄  █  █▀▀  █  █▄█ █ ▀█ █  █  ██▄
# [13:04:09 INFO]: [Kryptonite]
# [13:04:09 INFO]: [Kryptonite] Running Kryptonite version 1.4.0.
# [13:04:09 INFO]: [Kryptonite] Please report any issues with Kryptonite to our GitHub repository: https://github.com/lewmc/kryptonite/issues
# [13:04:09 INFO]: [Kryptonite]
# [13:04:09 INFO]: [Kryptonite] Beginning startup...
# [13:04:09 INFO]: [Kryptonite]
# [13:04:09 INFO]: [Kryptonite] You are running the latest version of Kryptonite.
# [13:04:09 INFO]: [Kryptonite]
# [13:04:09 WARN]: [Kryptonite] Unable to update YouHaveTrouble profile: java.lang.NullPointerException
# [13:04:09 WARN]: [Kryptonite] Unable to update FarmFriendly profile: java.lang.NullPointerException
# [13:04:09 INFO]: [Kryptonite] Running server jar: Paper version 1.21.4-R0.1-SNAPSHOT
# [13:04:09 INFO]: [Kryptonite] Supported configurations loaded: Server Properties, Bukkit, Spigot, Paper (World Defaults), Paper (Global).
# [13:04:09 INFO]: [Kryptonite]
# [13:04:09 INFO]: [Kryptonite] Startup completed.
# [13:04:09 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [13:04:10 INFO]: [hyperMOTD] Enabling hyperMOTD v1.0.2
# [13:04:10 INFO]: [gg.playit.minecraft.PlayitKeysSetup] secret key found, checking
# [13:04:10 INFO]: [gg.playit.minecraft.PlayitKeysSetup] check secret
# [13:04:10 INFO]: [AutoUpdatePlugins] Enabling AutoUpdatePlugins v10.5*
# [13:04:10 INFO]: [hyperMOTD] You are running the latest version.
# [13:04:11 INFO]: [spark] Starting background profiler...
# [13:04:11 INFO]: [gg.playit.minecraft.PlayitKeysSetup] found minecraft java tunnel: north-christianity.joinmc.link
# [13:04:11 INFO]: [gg.playit.minecraft.PlayitManager] keys and tunnel setup
# [13:04:11 INFO]: playit.gg: tunnel setup
# [13:04:11 INFO]: playit.gg: north-christianity.joinmc.link
# [13:04:12 INFO]: Done preparing level "Server-World" (18.380s)
# [13:04:12 INFO]: Running delayed init tasks
# [13:04:12 INFO]: [ViaVersion] Finished mapping loading, shutting down loader executor.
# [13:04:12 INFO]: [InventoryRollbackPlus] Checking for updates...
# [13:04:12 INFO]: Done (110.172s)! For help, type "help"
# [13:04:12 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [13:04:12 INFO]: [InventoryRollbackPlus] You are running the latest version.
# [13:04:12 INFO]: [ViaVersion] You are running a development version of the plugin, please report any bugs to GitHub.
# [13:04:13 INFO]: [gg.playit.control.ChannelSetup] request queued, waiting 1 second before resend
# [13:06:12 INFO]: [AutoUpdatePlugins] ViaVersion ---- https://ci.viaversion.com/job/ViaVersion/
# [13:06:13 INFO]: [AutoUpdatePlugins] ViaBackwards ---- https://ci.viaversion.com/view/ViaBackwards/job/ViaBackwards/
# [13:06:14 INFO]: [AutoUpdatePlugins] ViaRewind ---- https://ci.viaversion.com/view/ViaRewind/job/ViaRewind/
# [13:06:15 INFO]: [AutoUpdatePlugins] InventoryRollbackPlus ---- https://www.spigotmc.org/resources/inventory-rollback-plus.85811/
# [13:06:15 INFO]: [AutoUpdatePlugins] ProtocolLibDev ---- https://ci.dmulloy2.net/job/ProtocolLib/
# [13:06:16 INFO]: [AutoUpdatePlugins] PlayerStats ---- https://github.com/itHotL/PlayerStats
# [13:06:18 INFO]: [AutoUpdatePlugins] Thizzys Tree Feller ---- https://www.spigotmc.org/resources/thizzyz-tree-feller.64346/
# [13:06:18 INFO]: [AutoUpdatePlugins] hyperMOTD ---- https://github.com/hyperdefined/hyperMOTD
# [13:06:19 INFO]: [AutoUpdatePlugins] CoreProtect ---- https://www.spigotmc.org/resources/coreprotect.8631/
# [13:06:20 INFO]: [AutoUpdatePlugins] Download for CoreProtect was not successful
# [13:06:20 INFO]: [AutoUpdatePlugins] LightNewbie ---- https://www.spigotmc.org/resources/lightnewbie.117074/
# [13:08:15 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [13:09:14 WARN]: Can't keep up! Is the server overloaded? Running 2550ms or 51 ticks behind
# [13:09:15 INFO]: /playit
# [13:09:24 INFO]: Unknown or incomplete command, see below for error
# /playit<--[HERE]
# [13:09:37 INFO]: Unknown or incomplete command, see below for error
# /playit<--[HERE]
# [13:12:15 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# [13:16:16 INFO]: [gg.playit.control.ChannelSetup] send keep alive
# >....[13:19:55 INFO]: Stopping server
# [13:19:55 INFO]: [AutoUpdatePlugins] Disabling AutoUpdatePlugins v10.5
# [13:19:55 INFO]: [AntiBackdoor] Disabling AntiBackdoor v1.3.2
# [13:19:55 INFO]: [hyperMOTD] Disabling hyperMOTD v1.0.2
# [13:19:55 INFO]: [playit-gg] Disabling playit-gg v0.1.4
# [13:19:55 INFO]: [Kryptonite] Disabling Kryptonite v1.4.0
# [13:19:55 INFO]: [AntiWorldDownloader] Disabling AntiWorldDownloader v2.7.1.3
# [13:19:55 INFO]: [AntiWorldDownloader] AWD has been disabled! (Version: 2.7.1.3)
# [13:19:55 INFO]: [Protector] Disabling Protector v1.0
# [13:19:55 INFO]: [Protector] §cProtector has been disabled
# [13:19:55 INFO]: [GrimAC] Disabling GrimAC v2.3.69
# [13:19:55 INFO]: [GrimAC] Terminating PacketEvents...
# [13:19:55 INFO]: [DoubleDoors] Disabling DoubleDoors v1.4
# [13:19:55 INFO]: [DoubleDoors] DoubleDoors has been disabled!
# [13:19:55 INFO]: [ChunkyBorder] Disabling ChunkyBorder v1.2.23
# [13:19:55 INFO]: [LightNewbie] Disabling LightNewbie v1.9
# [13:19:55 INFO]: [LightNewbie] LightNewbie plugin has been disabled!
# [13:19:55 INFO]: [LightLeaf] Disabling LightLeaf v1.0
# [13:19:55 INFO]: [LuckPerms] Disabling LuckPerms v5.4.150
# [13:19:55 INFO]: [LuckPerms] Starting shutdown process...
# [13:19:55 INFO]: [LuckPerms] Closing storage...
# [13:19:56 INFO]: [gg.playit.minecraft.PlayitManager] control channel shutdown
# [13:19:56 INFO]: [LuckPerms] Goodbye!
# [13:19:56 INFO]: [InventoryRollbackPlus] Disabling InventoryRollbackPlus v1.6.21
# [13:19:56 INFO]: [InventoryRollbackPlus] Setting shutdown state
# [13:19:56 INFO]: [InventoryRollbackPlus] Saving player inventories...
# [13:19:56 INFO]: [InventoryRollbackPlus] Done saving player inventories!
# [13:19:56 INFO]: [InventoryRollbackPlus] Plugin is disabled!
# [13:19:56 INFO]: [PlayerStats] Disabling PlayerStats v2.3
# [13:19:56 INFO]: [PlayerStats] Disabled PlayerStats!
# [13:19:56 INFO]: [TreeFeller] Disabling TreeFeller v1.24.3
# [13:19:56 INFO]: [TreeFeller] TreeFeller has been disabled! (Version 1.24.3) by ThizThizzyDizzy
# [13:19:56 INFO]: [ViaRewind] Disabling ViaRewind v4.0.5-SNAPSHOT
# [13:19:56 INFO]: [ProtocolLib] Disabling ProtocolLib v5.4.0-SNAPSHOT-738
# [13:19:56 INFO]: [Chunky] Disabling Chunky v1.4.28
# [13:19:56 INFO]: [CoreProtect] Disabling CoreProtect v22.4
# [13:19:56 INFO]: [CoreProtect] Finishing up data logging. Please wait...
# [13:19:56 INFO]: [CoreProtect] Success! Disabled CoreProtect v22.4
# [13:19:56 INFO]: [ViaBackwards] Disabling ViaBackwards v5.2.1-SNAPSHOT
# [13:19:56 INFO]: [ViaVersion] Disabling ViaVersion v5.2.1-SNAPSHOT
# [13:19:56 INFO]: [ViaVersion] ViaVersion has been disabled; uninjected the platform and shut down the scheduler.
# [13:19:57 INFO]: Saving players
# [13:19:57 INFO]: Saving worlds
# [13:19:57 INFO]: Saving chunks for level 'ServerLevel[Server-World]'/minecraft:overworld
# [13:19:57 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'Server-World'
# [13:19:57 INFO]: [ChunkHolderManager] Halted chunk system for world 'Server-World'
# [13:19:57 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'Server-World'
# [13:19:57 INFO]: [ChunkHolderManager] Saved 0 block chunks, 3 entity chunks, 0 poi chunks in world 'Server-World' in 0.01s
# [13:19:57 INFO]: [ChunkHolderManager] Waiting 60s for chunk I/O to halt for world 'Server-World'
# [13:19:57 INFO]: [ChunkHolderManager] Halted I/O scheduler for world 'Server-World'
# [13:19:57 INFO]: Saving chunks for level 'ServerLevel[Server-World_nether]'/minecraft:the_nether
# [13:19:57 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'Server-World_nether'
# [13:19:57 INFO]: [ChunkHolderManager] Halted chunk system for world 'Server-World_nether'
# [13:19:57 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'Server-World_nether'
# [13:19:57 INFO]: [ChunkHolderManager] Saved 0 block chunks, 1 entity chunks, 0 poi chunks in world 'Server-World_nether' in 0.00s
# [13:19:57 INFO]: [ChunkHolderManager] Waiting 60s for chunk I/O to halt for world 'Server-World_nether'
# [13:19:57 INFO]: [ChunkHolderManager] Halted I/O scheduler for world 'Server-World_nether'
# [13:19:57 INFO]: Saving chunks for level 'ServerLevel[Server-World_the_end]'/minecraft:the_end
# [13:19:57 INFO]: [ChunkHolderManager] Waiting 60s for chunk system to halt for world 'Server-World_the_end'
# [13:19:57 INFO]: [ChunkHolderManager] Halted chunk system for world 'Server-World_the_end'
# [13:19:57 INFO]: [ChunkHolderManager] Saving all chunkholders for world 'Server-World_the_end'
# [13:19:57 INFO]: [ChunkHolderManager] Saved 0 block chunks, 10 entity chunks, 0 poi chunks in world 'Server-World_the_end' in 0.01s
# [13:19:57 INFO]: [ChunkHolderManager] Waiting 60s for chunk I/O to halt for world 'Server-World_the_end'
# [13:19:57 INFO]: [ChunkHolderManager] Halted I/O scheduler for world 'Server-World_the_end'
# [13:19:57 INFO]: ThreadedAnvilChunkStorage (Server-World): All chunks are saved
# [13:19:57 INFO]: ThreadedAnvilChunkStorage (DIM-1): All chunks are saved
# [13:19:57 INFO]: ThreadedAnvilChunkStorage (DIM1): All chunks are saved
# [13:19:57 INFO]: ThreadedAnvilChunkStorage: All dimensions are saved
# [13:19:57 INFO]: Waiting for I/O tasks to complete...
# [13:19:57 INFO]: All I/O tasks to complete
# [13:19:57 INFO]: [MoonriseCommon] Awaiting termination of worker pool for up to 60s...
# [13:19:57 INFO]: [MoonriseCommon] Awaiting termination of I/O pool for up to 60s...

# %% [markdown]
# ### FAQ - Essential Information
#
# While Google Colab is not made for hosting Minecraft servers. Its is possible to set one up. Here are some things to take away from this:
#
# - **Session Duration**: Google Colab sessions can run for up to 82 hours! but they might turn off the server if the page is inactive for a really long time! To keep your server running (so you players won't be annoyed!) you have to keep your server tab open as much as possible
#
# - **Performance Specs**: Google Colab provides around **12 GB** of RAM, a 2.2 GHz processor with 2 threads, which can outperform many paid hosting services. However, it lacks any support from google, so if anything goes wrong you're on your own!
#
# - **Mod and Plugin Limitations**: While you can install mods and plugins, it’s advisied to **not** overload the server with too many! As this can impact performance! To reduce this lag try to install a plugin like [LightOptimizer](https://www.spigotmc.org/resources/lightoptimizer-%E2%9A%A1-server-performance-booster-fps-helper-%E2%9A%A1.117477/) or a modpack like [1.21 Server Optimizations](https://modrinth.com/collection/YnSBBMnH)
#
# - **Best Use Cases**: If you’re planning to make a small Minecraft server for a few players or a smp (btw call it the colab smp XD) this is the perfect option! But, if you are thinking of making a server with more players, i'd recommend you to either buy a server or self host it on an old computer or cheap computer them you upgrade it to make it possible to host a server!.
